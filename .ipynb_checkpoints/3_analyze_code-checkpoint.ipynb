# %% [markdown]
# ### Analyze code to detect code smells
# Ideally, code smells need to be tagged manually to create a proper dataset.
# However, a shortcut is to use existing tools to come up with a training dataset.
# We will first use an existing tool DesigniteJava to detect smells and compute metrics.
# Then, we will use the metrics as features and tool detected smells to prepare our dataset.

# %%
import os
import analyze_code

repos_folder = os.path.join('data', 'repos')
analyazed_repos_folder = os.path.join('data', 'analyzed_repos')

for folder in os.listdir(repos_folder):
    folder_path = os.path.join(repos_folder, folder)
    result_path = os.path.join(analyazed_repos_folder, folder)
    if os.path.isdir(folder_path):
        analyze_code.analyze_repo(folder_path, result_path, os.path.abspath('apps/DJ/DesigniteJava.jar'))
# Out:
# Analyzing data/repos/pmd_pmd ...
# Attempting compilation...
# Found pom.xml
# [INFO] Scanning for projects...
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/plugins/nexus-staging-maven-plugin/1.7.0/nexus-staging-maven-plugin-1.7.0.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/plugins/nexus-staging-maven-plugin/1.7.0/nexus-staging-maven-plugin-1.7.0.pom (9.1 kB at 31 kB/s)
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/maven/nexus-staging/1.7.0/nexus-staging-1.7.0.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/maven/nexus-staging/1.7.0/nexus-staging-1.7.0.pom (2.8 kB at 86 kB/s)
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/maven/nexus-maven-plugins/1.7.0/nexus-maven-plugins-1.7.0.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/maven/nexus-maven-plugins/1.7.0/nexus-maven-plugins-1.7.0.pom (19 kB at 505 kB/s)
# [INFO] Artifact org.sonatype.buildsupport:public-parent:pom:32 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# [INFO] Artifact org.sonatype.buildsupport:public-parent:pom:32 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/buildsupport/public-parent/32/public-parent-32.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/buildsupport/public-parent/32/public-parent-32.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.buildsupport:buildsupport:pom:32 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# [INFO] Artifact org.sonatype.buildsupport:buildsupport:pom:32 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/buildsupport/buildsupport/32/buildsupport-32.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/buildsupport/buildsupport/32/buildsupport-32.pom (0 B at 0 B/s)
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/maven/nexus-common/1.7.0/nexus-common-1.7.0.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/maven/nexus-common/1.7.0/nexus-common-1.7.0.pom (2.2 kB at 72 kB/s)
# [INFO] Artifact org.sonatype.plexus:plexus-cipher:pom:1.7 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# [INFO] Artifact org.sonatype.plexus:plexus-cipher:pom:1.7 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/plexus/plexus-cipher/1.7/plexus-cipher-1.7.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/plexus/plexus-cipher/1.7/plexus-cipher-1.7.pom (0 B at 0 B/s)
# [INFO] Artifact org.apache.maven:maven-plugin-api:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# [INFO] Artifact org.apache.maven:maven-plugin-api:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-plugin-api/3.0.4/maven-plugin-api-3.0.4.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-plugin-api/3.0.4/maven-plugin-api-3.0.4.pom (0 B at 0 B/s)
# [INFO] Artifact org.apache.maven:maven:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# [INFO] Artifact org.apache.maven:maven:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven/3.0.4/maven-3.0.4.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven/3.0.4/maven-3.0.4.pom (0 B at 0 B/s)
# [INFO] Artifact org.apache.maven:maven-model:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# [INFO] Artifact org.apache.maven:maven-model:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-model/3.0.4/maven-model-3.0.4.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-model/3.0.4/maven-model-3.0.4.pom (0 B at 0 B/s)
# [INFO] Artifact org.apache.maven:maven-artifact:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# [INFO] Artifact org.apache.maven:maven-artifact:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-artifact/3.0.4/maven-artifact-3.0.4.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-artifact/3.0.4/maven-artifact-3.0.4.pom (0 B at 0 B/s)
# [INFO] Artifact org.apache.maven:maven-compat:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# [INFO] Artifact org.apache.maven:maven-compat:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-compat/3.0.4/maven-compat-3.0.4.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-compat/3.0.4/maven-compat-3.0.4.pom (0 B at 0 B/s)
# [INFO] Artifact org.apache.maven:maven-model-builder:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# [INFO] Artifact org.apache.maven:maven-model-builder:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-model-builder/3.0.4/maven-model-builder-3.0.4.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-model-builder/3.0.4/maven-model-builder-3.0.4.pom (0 B at 0 B/s)
# [INFO] Artifact org.apache.maven:maven-settings:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# [INFO] Artifact org.apache.maven:maven-settings:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-settings/3.0.4/maven-settings-3.0.4.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-settings/3.0.4/maven-settings-3.0.4.pom (0 B at 0 B/s)
# [INFO] Artifact org.apache.maven:maven-core:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# [INFO] Artifact org.apache.maven:maven-core:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-core/3.0.4/maven-core-3.0.4.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-core/3.0.4/maven-core-3.0.4.pom (0 B at 0 B/s)
# [INFO] Artifact org.apache.maven:maven-settings-builder:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# [INFO] Artifact org.apache.maven:maven-settings-builder:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-settings-builder/3.0.4/maven-settings-builder-3.0.4.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-settings-builder/3.0.4/maven-settings-builder-3.0.4.pom (0 B at 0 B/s)
# [INFO] Artifact org.apache.maven:maven-repository-metadata:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# [INFO] Artifact org.apache.maven:maven-repository-metadata:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-repository-metadata/3.0.4/maven-repository-metadata-3.0.4.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-repository-metadata/3.0.4/maven-repository-metadata-3.0.4.pom (0 B at 0 B/s)
# [INFO] Artifact org.apache.maven:maven-aether-provider:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# [INFO] Artifact org.apache.maven:maven-aether-provider:pom:3.0.4 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-aether-provider/3.0.4/maven-aether-provider-3.0.4.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/apache/maven/maven-aether-provider/3.0.4/maven-aether-provider-3.0.4.pom (0 B at 0 B/s)
# [INFO] Artifact org.apache.maven.wagon:wagon-provider-api:pom:2.2 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# [INFO] Artifact org.apache.maven.wagon:wagon-provider-api:pom:2.2 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/apache/maven/wagon/wagon-provider-api/2.2/wagon-provider-api-2.2.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/apache/maven/wagon/wagon-provider-api/2.2/wagon-provider-api-2.2.pom (0 B at 0 B/s)
# [INFO] Artifact org.apache.maven.wagon:wagon:pom:2.2 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# [INFO] Artifact org.apache.maven.wagon:wagon:pom:2.2 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), maven-default-http-blocker (http://0.0.0.0/, default, snapshots, blocked)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/apache/maven/wagon/wagon/2.2/wagon-2.2.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/apache/maven/wagon/wagon/2.2/wagon-2.2.pom (0 B at 0 B/s)
# [INFO] Artifact org.apache.maven.plugin-tools:maven-plugin-annotations:pom:3.2 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# [INFO] Artifact org.apache.maven.plugin-tools:maven-plugin-annotations:pom:3.2 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/apache/maven/plugin-tools/maven-plugin-annotations/3.2/maven-plugin-annotations-3.2.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/apache/maven/plugin-tools/maven-plugin-annotations/3.2/maven-plugin-annotations-3.2.pom (0 B at 0 B/s)
# [INFO] Artifact org.apache.maven.plugin-tools:maven-plugin-tools:pom:3.2 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# [INFO] Artifact org.apache.maven.plugin-tools:maven-plugin-tools:pom:3.2 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/apache/maven/plugin-tools/maven-plugin-tools/3.2/maven-plugin-tools-3.2.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/apache/maven/plugin-tools/maven-plugin-tools/3.2/maven-plugin-tools-3.2.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.nexus:nexus-client-core:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# [INFO] Artifact org.sonatype.nexus:nexus-client-core:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/nexus-client-core/2.15.1-02/nexus-client-core-2.15.1-02.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/nexus-client-core/2.15.1-02/nexus-client-core-2.15.1-02.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.nexus:nexus-components:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# [INFO] Artifact org.sonatype.nexus:nexus-components:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/nexus-components/2.15.1-02/nexus-components-2.15.1-02.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/nexus-components/2.15.1-02/nexus-components-2.15.1-02.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.nexus:nexus-parent:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# [INFO] Artifact org.sonatype.nexus:nexus-parent:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/nexus-parent/2.15.1-02/nexus-parent-2.15.1-02.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/nexus-parent/2.15.1-02/nexus-parent-2.15.1-02.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.buildsupport:public-parent:pom:9 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots)]
# [INFO] Artifact org.sonatype.buildsupport:public-parent:pom:9 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/buildsupport/public-parent/9/public-parent-9.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/buildsupport/public-parent/9/public-parent-9.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.buildsupport:buildsupport:pom:9 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots)]
# [INFO] Artifact org.sonatype.buildsupport:buildsupport:pom:9 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/buildsupport/buildsupport/9/buildsupport-9.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/buildsupport/buildsupport/9/buildsupport-9.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-all:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots)]
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-all:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/buildsupport/nexus-buildsupport-all/2.15.1-02/nexus-buildsupport-all-2.15.1-02.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/buildsupport/nexus-buildsupport-all/2.15.1-02/nexus-buildsupport-all-2.15.1-02.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots)]
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [central (https://repo.maven.apache.org/maven2, default, releases), sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots)]
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/buildsupport/nexus-buildsupport/2.15.1-02/nexus-buildsupport-2.15.1-02.pom
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/nexus/buildsupport/nexus-buildsupport/2.15.1-02/nexus-buildsupport-2.15.1-02.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-commons:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-commons:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# Downloading from rso-public-grid: https://repository.sonatype.org/content/groups/sonatype-public-grid/org/sonatype/nexus/buildsupport/nexus-buildsupport-commons/2.15.1-02/nexus-buildsupport-commons-2.15.1-02.pom
# Downloaded from rso-public-grid: https://repository.sonatype.org/content/groups/sonatype-public-grid/org/sonatype/nexus/buildsupport/nexus-buildsupport-commons/2.15.1-02/nexus-buildsupport-commons-2.15.1-02.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-db:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-db:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# Downloading from rso-public-grid: https://repository.sonatype.org/content/groups/sonatype-public-grid/org/sonatype/nexus/buildsupport/nexus-buildsupport-db/2.15.1-02/nexus-buildsupport-db-2.15.1-02.pom
# Downloaded from rso-public-grid: https://repository.sonatype.org/content/groups/sonatype-public-grid/org/sonatype/nexus/buildsupport/nexus-buildsupport-db/2.15.1-02/nexus-buildsupport-db-2.15.1-02.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-gwt:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-gwt:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# Downloading from rso-public-grid: https://repository.sonatype.org/content/groups/sonatype-public-grid/org/sonatype/nexus/buildsupport/nexus-buildsupport-gwt/2.15.1-02/nexus-buildsupport-gwt-2.15.1-02.pom
# Downloaded from rso-public-grid: https://repository.sonatype.org/content/groups/sonatype-public-grid/org/sonatype/nexus/buildsupport/nexus-buildsupport-gwt/2.15.1-02/nexus-buildsupport-gwt-2.15.1-02.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-httpclient:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-httpclient:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# Downloading from rso-public-grid: https://repository.sonatype.org/content/groups/sonatype-public-grid/org/sonatype/nexus/buildsupport/nexus-buildsupport-httpclient/2.15.1-02/nexus-buildsupport-httpclient-2.15.1-02.pom
# Downloaded from rso-public-grid: https://repository.sonatype.org/content/groups/sonatype-public-grid/org/sonatype/nexus/buildsupport/nexus-buildsupport-httpclient/2.15.1-02/nexus-buildsupport-httpclient-2.15.1-02.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-insight:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-insight:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# Downloading from rso-public-grid: https://repository.sonatype.org/content/groups/sonatype-public-grid/org/sonatype/nexus/buildsupport/nexus-buildsupport-insight/2.15.1-02/nexus-buildsupport-insight-2.15.1-02.pom
# Downloaded from rso-public-grid: https://repository.sonatype.org/content/groups/sonatype-public-grid/org/sonatype/nexus/buildsupport/nexus-buildsupport-insight/2.15.1-02/nexus-buildsupport-insight-2.15.1-02.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-maven:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-maven:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# Downloading from rso-public-grid: https://repository.sonatype.org/content/groups/sonatype-public-grid/org/sonatype/nexus/buildsupport/nexus-buildsupport-maven/2.15.1-02/nexus-buildsupport-maven-2.15.1-02.pom
# Downloaded from rso-public-grid: https://repository.sonatype.org/content/groups/sonatype-public-grid/org/sonatype/nexus/buildsupport/nexus-buildsupport-maven/2.15.1-02/nexus-buildsupport-maven-2.15.1-02.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-messaging:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-messaging:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# Downloading from rso-public-grid: https://repository.sonatype.org/content/groups/sonatype-public-grid/org/sonatype/nexus/buildsupport/nexus-buildsupport-messaging/2.15.1-02/nexus-buildsupport-messaging-2.15.1-02.pom
# Downloaded from rso-public-grid: https://repository.sonatype.org/content/groups/sonatype-public-grid/org/sonatype/nexus/buildsupport/nexus-buildsupport-messaging/2.15.1-02/nexus-buildsupport-messaging-2.15.1-02.pom (0 B at 0 B/s)
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-shiro:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# [INFO] Artifact org.sonatype.nexus.buildsupport:nexus-buildsupport-shiro:pom:2.15.1-02 is present in the local repository, but cached from a remote repository ID that is unavailable in current build context, verifying that is downloadable from [sonatype-nexus-plugin-snapshots (https://oss.sonatype.org/content/repositories/snapshots, default, snapshots), apache.snapshots (https://repository.apache.org/snapshots, default, snapshots), rso-public-grid (https://repository.sonatype.org/content/groups/sonatype-public-grid/, default, releases+snapshots), central (https://repo.maven.apache.org/maven2, default, releases)]
# Downloading from rso-public-grid: https://repository.sonatype.org/content/groups/sonatype-public-grid/org/sonatype/nexus/buildsupport/nexus-buildsupport-shiro/2.15.1-02/nexus-buildsupport-shiro-2.15.1-02.pom
# ...
# [INFO]      [java] Warning: Choice conflict in (...)* construct at line 3372, column 3.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "<"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 3417, column 5.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "ESCAPE"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in (...)* construct at line 3436, column 3.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "+"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict involving two expansions at
# [INFO]      [java]          line 3489, column 4 and line 3495, column 4 respectively.
# [INFO]      [java]          A common prefix is: "PRIOR" "AT"
# [INFO]      [java]          Consider using a lookahead of 3 or more for earlier expansion.
# [INFO]      [java] Warning: Choice conflict involving two expansions at
# [INFO]      [java]          line 3544, column 5 and line 3548, column 5 respectively.
# [INFO]      [java]          A common prefix is: "NOT" "AT"
# [INFO]      [java]          Consider using a lookahead of 3 or more for earlier expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 3586, column 11.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "ONLY"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 3586, column 32.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "ONLY"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 3591, column 11.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "ONLY"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 3591, column 32.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "ONLY"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 3636, column 63.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "OVER"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 3636, column 84.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "WITHIN"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict involving two expansions at
# [INFO]      [java]          line 3676, column 21 and line 3679, column 21 respectively.
# [INFO]      [java]          A common prefix is: "DBTIMEZONE"
# [INFO]      [java]          Consider using a lookahead of 2 for earlier expansion.
# [INFO]      [java] Warning: Choice conflict involving two expansions at
# [INFO]      [java]          line 3677, column 21 and line 3679, column 21 respectively.
# [INFO]      [java]          A common prefix is: "SESSIONTIMEZONE"
# [INFO]      [java]          Consider using a lookahead of 2 for earlier expansion.
# [INFO]      [java] Warning: Choice conflict involving two expansions at
# [INFO]      [java]          line 3678, column 21 and line 3679, column 21 respectively.
# [INFO]      [java]          A common prefix is: <STRING_LITERAL>
# [INFO]      [java]          Consider using a lookahead of 2 for earlier expansion.
# [INFO]      [java] Warning: Choice conflict in (...)* construct at line 3841, column 9.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "."
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict involving two expansions at
# [INFO]      [java]          line 3852, column 42 and line 3852, column 48 respectively.
# [INFO]      [java]          A common prefix is: "*"
# [INFO]      [java]          Consider using a lookahead of 2 for earlier expansion.
# [INFO]      [java] Warning: Choice conflict involving two expansions at
# [INFO]      [java]          line 3923, column 17 and line 3932, column 17 respectively.
# [INFO]      [java]          A common prefix is: "TIMESTAMP" "("
# [INFO]      [java]          Consider using a lookahead of 3 or more for earlier expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 3980, column 9.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "PACKAGE"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 3982, column 9.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "PACKAGE"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict involving two expansions at
# [INFO]      [java]          line 4141, column 9 and line 4143, column 9 respectively.
# [INFO]      [java]          A common prefix is: "CURRENT_USER"
# [INFO]      [java]          Consider using a lookahead of 2 for earlier expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 4212, column 9.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "IS"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict involving two expansions at
# [INFO]      [java]          line 4216, column 19 and line 4219, column 19 respectively.
# [INFO]      [java]          A common prefix is: "LANGUAGE" <IDENTIFIER>
# [INFO]      [java]          Consider using a lookahead of 3 or more for earlier expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 4217, column 19.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: ";"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 4273, column 102.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "."
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict involving two expansions at
# [INFO]      [java]          line 4298, column 26 and line 4298, column 41 respectively.
# [INFO]      [java]          A common prefix is: "NOT" "OVERRIDING"
# [INFO]      [java]          Consider using a lookahead of 3 or more for earlier expansion.
# [INFO]      [java] Warning: Choice conflict in (...)* construct at line 4315, column 9.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "ALTER"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 4318, column 9.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "/"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in (...)* construct at line 4320, column 9.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "ALTER"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in (...)* construct at line 4341, column 8.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "DROP"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in (...)+ construct at line 4345, column 9.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "NOT"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in (...)* construct at line 4356, column 21.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: ","
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in (...)+ construct at line 4368, column 9.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "ATTRIBUTE"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in (...)* construct at line 4373, column 21.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: ","
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 4415, column 9.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: <IDENTIFIER>
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict involving two expansions at
# [INFO]      [java]          line 4644, column 9 and line 4646, column 10 respectively.
# [INFO]      [java]          A common prefix is: "DATABASE"
# [INFO]      [java]          Consider using a lookahead of 2 for earlier expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 4710, column 5.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "AFTER"
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] Warning: Choice conflict involving two expansions at
# [INFO]      [java]          line 4733, column 3 and line 4733, column 16 respectively.
# [INFO]      [java]          A common prefix is: "DATABASE"
# [INFO]      [java]          Consider using a lookahead of 2 for earlier expansion.
# [INFO]      [java] Warning: Choice conflict in [...] construct at line 7063, column 10.
# [INFO]      [java]          Expansion nested within construct and expansion following construct
# [INFO]      [java]          have common prefixes, one of which is: "("
# [INFO]      [java]          Consider using a lookahead of 2 or more for nested expansion.
# [INFO]      [java] File "TokenMgrError.java" does not exist.  Will create one.
# [INFO]      [java] File "ParseException.java" does not exist.  Will create one.
# [INFO]      [java] File "Token.java" does not exist.  Will create one.
# [INFO]      [java] File "CharStream.java" does not exist.  Will create one.
# [INFO]      [java] Parser generated with 0 errors and 96 warnings.
# [INFO]      [java] Warning: Line 5347, Column 1: Regular Expression choice : ID_SIMPLE can never be matched as : IDENTIFIER
# [INFO]    [delete] Deleting: /Users/mootez/courses/w25/6314/labs/lab3/W25-CSCI-6314-4130-Lab-3/data/repos/pmd_pmd/pmd-plsql/target/generated-sources/javacc/net/sourceforge/pmd/lang/plsql/ast/Node.java
# [INFO]    [delete] Deleting: /Users/mootez/courses/w25/6314/labs/lab3/W25-CSCI-6314-4130-Lab-3/data/repos/pmd_pmd/pmd-plsql/target/generated-sources/javacc/net/sourceforge/pmd/lang/plsql/ast/SimpleNode.java
# [INFO]    [delete] Deleting: /Users/mootez/courses/w25/6314/labs/lab3/W25-CSCI-6314-4130-Lab-3/data/repos/pmd_pmd/pmd-plsql/target/generated-sources/javacc/net/sourceforge/pmd/lang/plsql/ast/JJTPLSQLParserImplState.java
# [INFO]    [delete] Deleting: /Users/mootez/courses/w25/6314/labs/lab3/W25-CSCI-6314-4130-Lab-3/data/repos/pmd_pmd/pmd-plsql/target/generated-sources/javacc/net/sourceforge/pmd/lang/plsql/ast/CharStream.java
# [INFO]    [delete] Deleting: /Users/mootez/courses/w25/6314/labs/lab3/W25-CSCI-6314-4130-Lab-3/data/repos/pmd_pmd/pmd-plsql/target/generated-sources/javacc/net/sourceforge/pmd/lang/plsql/ast/ParseException.java
# [INFO]    [delete] Deleting: /Users/mootez/courses/w25/6314/labs/lab3/W25-CSCI-6314-4130-Lab-3/data/repos/pmd_pmd/pmd-plsql/target/generated-sources/javacc/net/sourceforge/pmd/lang/plsql/ast/Token.java
# [INFO]    [delete] Deleting: /Users/mootez/courses/w25/6314/labs/lab3/W25-CSCI-6314-4130-Lab-3/data/repos/pmd_pmd/pmd-plsql/target/generated-sources/javacc/net/sourceforge/pmd/lang/plsql/ast/TokenMgrError.java
# [INFO]      [move] Moving 1 file to /Users/mootez/courses/w25/6314/labs/lab3/W25-CSCI-6314-4130-Lab-3/data/repos/pmd_pmd/pmd-plsql/target/generated-sources/javacc/net/sourceforge/pmd/lang/plsql/ast
# [INFO]      [move] Moving 1 file to /Users/mootez/courses/w25/6314/labs/lab3/W25-CSCI-6314-4130-Lab-3/data/repos/pmd_pmd/pmd-plsql/target/generated-sources/javacc/net/sourceforge/pmd/lang/plsql/ast
# [INFO] Executed tasks
# [INFO]
# [INFO] --- build-helper:3.6.0:add-source (add-kotlin-source-dir) @ pmd-plsql ---
# [INFO] Source directory: /Users/mootez/courses/w25/6314/labs/lab3/W25-CSCI-6314-4130-Lab-3/data/repos/pmd_pmd/pmd-plsql/src/main/kotlin added.
# [INFO]
# [INFO] --- build-helper:3.6.0:add-source (add-javacc-generated-sources) @ pmd-plsql ---
# [INFO] Source directory: /Users/mootez/courses/w25/6314/labs/lab3/W25-CSCI-6314-4130-Lab-3/data/repos/pmd_pmd/pmd-plsql/target/generated-sources/javacc added.
# [INFO]
# [INFO] --- resources:3.3.1:resources (default-resources) @ pmd-plsql ---
# [INFO] Copying 10 resources from src/main/resources to target/classes
# [INFO]
# [INFO] --- compiler:3.13.0:compile (java-compile) @ pmd-plsql ---
# [INFO] Recompiling the module because of changed dependency.
# [INFO] Compiling 278 source files with javac [debug release 8] to target/classes
